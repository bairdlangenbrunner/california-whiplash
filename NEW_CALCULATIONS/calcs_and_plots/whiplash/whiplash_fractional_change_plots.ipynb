# %%
import numpy
import matplotlib.pyplot as mp

mp.rcParams.update({'mathtext.default': 'regular'})
% matplotlib inline

# %%
NCAL_8020_2070_2100 = numpy.array(( \
0.5378632478632479, \
0.7386150234741784, \
0.8260042735042736, \
0.42026422764227633, \
0.4777294685990338, \
0.5428743961352657, \
0.3474396135265701, \
0.5150520833333333, \
0.5949264705882352 ))

CCAL_8020_2070_2100 = numpy.array(( \
1.1387333333333336, \
1.1059126984126983, \
1.3011842105263158, \
1.0241772151898734, \
0.9567670682730924, \
1.220864197530864, \
0.8172727272727274, \
1.0049796747967479, \
1.1759071729957806 ))

SCAL_8020_2070_2100 = numpy.array(( \
1.7186764705882351, \
1.7337857142857143, \
1.8521064814814816, \
1.4572831050228314, \
1.5574780701754387, \
1.6182000000000003, \
1.358488888888889, \
1.4778082191780824, \
1.4786184210526316 ))

NCAL_8020_2005_2035 = numpy.array(( \
0.998888888888889, \
1.1817840375586857, \
1.1141452991452991, \
0.9318902439024389, \
1.0857487922705313, \
1.0640338164251208, \
1.1508937198067635, \
1.2408072916666668, \
1.255955882352941 ))

CCAL_8020_2005_2035 = numpy.array(( \
1.0788000000000002, \
1.0345634920634919, \
1.3011842105263158, \
0.9672784810126582, \
1.028975903614458, \
1.1653703703703704, \
1.0896969696969698, \
1.1877032520325201, \
1.3086708860759493 ))

SCAL_8020_2005_2035 = numpy.array(( \
1.6525735294117647, \
1.4341190476190475, \
1.4775231481481483, \
1.4162328767123291, \
1.380043859649123, \
1.4184222222222225, \
1.2186444444444446, \
1.272557077625571, \
1.360328947368421 ))

NCAL_8020_1920_1950 = numpy.array(( \
0.595491452991453, \
0.6542018779342724, \
0.8452136752136752, \
0.6760772357723577, \
0.760024154589372, \
0.8903140096618357, \
0.9120289855072465, \
0.9832812500000002, \
0.8373039215686274 ))

CCAL_8020_1920_1950 = numpy.array(( \
0.8790222222222224, \
0.9275396825396826, \
1.0646052631578948, \
0.8155485232067511, \
0.9026104417670681, \
0.943395061728395, \
0.9534848484848484, \
0.8770731707317072, \
0.8345147679324894 ))

SCAL_8020_1920_1950 = numpy.array(( \
1.1898529411764704, \
1.1986666666666668, \
1.227800925925926, \
1.1699315068493152, \
1.12375, \
1.0788000000000002, \
1.0987777777777779, \
1.128881278538813, \
1.0843201754385965 ))

# %%
fontsize=12
fig = mp.figure(figsize=(8,3))

ax = fig.add_subplot(111)
ax.axhline(1, lw=2, c='0.25', zorder=0)

ax.scatter([1]*9, NCAL_8020_2070_2100, c='firebrick', s=25)
ax.scatter([2]*9, CCAL_8020_2070_2100, c='firebrick', s=25)
ax.scatter([3]*9, SCAL_8020_2070_2100, c='firebrick', s=25)
ax.text(s='2070-2100', x=2, y=2.3, ha='center', va='bottom', fontsize=fontsize, color='firebrick')

ax.scatter([5]*9, NCAL_8020_2005_2035, c='darkcyan', s=25)
ax.scatter([6]*9, CCAL_8020_2005_2035, c='darkcyan', s=25)
ax.scatter([7]*9, SCAL_8020_2005_2035, c='darkcyan', s=25)
ax.text(s='2005-2035', x=6, y=2.3, ha='center', va='bottom', fontsize=fontsize, color='darkcyan')

ax.scatter([9]*9, NCAL_8020_1920_1950, c='0.25', s=25)
ax.scatter([10]*9, CCAL_8020_1920_1950, c='0.25', s=25)
ax.scatter([11]*9, SCAL_8020_1920_1950, c='0.25', s=25)
ax.text(s='1920-1950', x=10, y=2.3, ha='center', va='bottom', fontsize=fontsize, color='0.25')

ax.text(s='$>$ 80% high(single season)\n$<$ 20% low (3-season mean)', x=0.96, y=0.02, ha='right', va='bottom', fontsize=fontsize, transform=ax.transAxes)
ax.set_xticklabels(['N.Cal.', 'C.Cal.', 'S.Cal.','N.Cal.', 'C.Cal.', 'S.Cal.','N.Cal.', 'C.Cal.', 'S.Cal.'])
ax.set_xticks([1,2,3,5,6,7,9,10,11])
ax.set_xlim(0,12)
ax.set_ylim(-0.25,2.25)

ax.tick_params(labelsize=fontsize)
ax.grid()
ax.set_axisbelow(True)

# %%
# SCAL 80-20
# 1920-50
# 1950-80
# 1980-2010
# 2010-2040
# 2040-2070
# 2070-2100

col1 = numpy.array((
1.1898529411764704, \
1.1986666666666668, \
1.227800925925926, \
1.1699315068493152, \
1.12375, \
1.0788000000000002, \
1.0987777777777779, \
1.128881278538813, \
1.0843201754385965))
col2 = numpy.array((
0.903406862745098, \
1.0060238095238097, \
0.894837962962963, \
0.9236301369863015, \
1.0448903508771932, \
1.0588222222222226, \
0.839066666666667, \
0.9852054794520549, \
0.9463157894736842))
col3 = numpy.array((
1.2118872549019606, \
1.1558571428571427, \
1.0196990740740741, \
1.0878310502283108, \
1.1828947368421054, \
1.1587111111111112, \
1.0588222222222226, \
1.1699315068493152, \
1.0646052631578948))
col4 = numpy.array((
1.564436274509804, \
1.369904761904762, \
1.435902777777778, \
1.4162328767123291, \
1.3011842105263158, \
1.298555555555556, \
1.2186444444444446, \
1.2520319634703199, \
1.2420394736842106))
col5 = numpy.array((
1.6525735294117647, \
1.4769285714285714, \
1.3734722222222222, \
1.5599086757990872, \
1.4983333333333335, \
1.378466666666667, \
1.378466666666667, \
1.43675799086758, \
1.3011842105263158))
col6 = numpy.array((
1.7186764705882351, \
1.7337857142857143, \
1.8521064814814816, \
1.4572831050228314, \
1.5574780701754387, \
1.6182000000000003, \
1.358488888888889, \
1.4778082191780824, \
1.4786184210526316))

# %%
fontsize=12
fig = mp.figure(figsize=(5,3))

ax = fig.add_subplot(111)
ax.axhline(1, lw=2, c='0.25', zorder=0)

ax.scatter([1]*9, col1, c='firebrick', s=25)
ax.scatter([2]*9, col2, c='firebrick', s=25)
ax.scatter([3]*9, col3, c='firebrick', s=25)
ax.scatter([4]*9, col4, c='firebrick', s=25)
ax.scatter([5]*9, col5, c='firebrick', s=25)
ax.scatter([6]*9, col6, c='firebrick', s=25)

ax.set_xlim(0,7)
ax.tick_params(labelsize=fontsize)
ax.grid()
ax.set_axisbelow(True)
ax.set_ylim(0.5,2.25)
ax.set_xticks([1,2,3,4,5,6])
ax.set_xticklabels(['1920-\n1950', '1950-\n1980', '1980-\n2010', '2010-\n2040', '2040-\n2070', '2070-\n2100'])
ax.text(s='S. California whiplash fractional change (80%-20%)', x=0, y=1.03, transform=ax.transAxes, ha='left', va='bottom', fontsize=fontsize)

# %%
fontsize=12
fig = mp.figure(figsize=(5,3))

ax = fig.add_subplot(111)
ax.axhline(1, lw=2, c='0.25', zorder=0)

ax.scatter([1]*9, NCAL_8020_2070_2100, c='firebrick', s=25)
ax.scatter([2]*9, CCAL_8020_2070_2100, c='firebrick', s=25)
ax.scatter([3]*9, SCAL_8020_2070_2100, c='firebrick', s=25)
ax.text(s='2070-2100', x=2, y=2.3, ha='center', va='bottom', fontsize=fontsize, color='firebrick')

ax.scatter([5]*9, NCAL_8020_2005_2035, c='darkcyan', s=25)
ax.scatter([6]*9, CCAL_8020_2005_2035, c='darkcyan', s=25)
ax.scatter([7]*9, SCAL_8020_2005_2035, c='darkcyan', s=25)
ax.text(s='2005-2035', x=6, y=2.3, ha='center', va='bottom', fontsize=fontsize, color='darkcyan')

ax.text(s='$>$ 80% high(single season)\n$<$ 20% low (3-season mean)', x=0.96, y=0.05, ha='right', va='bottom', fontsize=fontsize, transform=ax.transAxes)
ax.set_xticklabels(['N.Cal.', 'C.Cal.', 'S.Cal.','N.Cal.', 'C.Cal.', 'S.Cal.'])
ax.set_xticks([1,2,3,5,6,7,9,10,11])
ax.set_xlim(0,8)
ax.set_ylim(0,2.25)

ax.tick_params(labelsize=fontsize)
ax.grid()
ax.set_axisbelow(True)

# %%
fontsize=12
fig = mp.figure(figsize=(8.5,3))

ax = fig.add_subplot(111)

ax.axhline(0,lw=2,c='0.1', zorder=1)

boxplot_width=[0.5]
#ax.scatter([1]*N_ens, subensembles_delta_pr_ncal, zorder=2)
#ax.scatter([2]*N_ens, subensembles_delta_pr_ccal, zorder=2)
#ax.scatter([3]*N_ens, subensembles_delta_pr_scal, zorder=2)

flierprops = dict(marker='.', markeredgecolor='0.1', markerfacecolor='0.1')
medianprops = dict(linewidth=2, color='firebrick')
boxprops = dict(linewidth=2, color='0.1')
whiskerprops = dict(linewidth=2, color='0.1')
capprops = dict(linewidth=2, color='0.1')

ax.boxplot(model_delta_pr_ncal, zorder=2, positions=[1.0], whis='range', widths=boxplot_width, flierprops=flierprops, medianprops=medianprops, boxprops=boxprops, whiskerprops=whiskerprops, capprops=capprops)
ax.boxplot(model_delta_pr_ccal, zorder=2, positions=[2.0], whis='range', widths=boxplot_width, flierprops=flierprops, medianprops=medianprops, boxprops=boxprops, whiskerprops=whiskerprops, capprops=capprops)
ax.boxplot(model_delta_pr_scal, zorder=2, positions=[3.0], whis='range', widths=boxplot_width, flierprops=flierprops, medianprops=medianprops, boxprops=boxprops, whiskerprops=whiskerprops, capprops=capprops)

ax.text(s='original\nCMIP5 models', x=2.0, y=3.3, fontsize=fontsize, ha='center', va='bottom', color='firebrick')


flierprops = dict(marker='.', markeredgecolor='0.1', markerfacecolor='0.1')
medianprops = dict(linewidth=2, color='firebrick')
boxprops = dict(linewidth=2, color='0.1')
whiskerprops = dict(linewidth=2, color='0.1')
capprops = dict(linewidth=2, color='0.1')

ax.boxplot(subensembles_delta_pr_ncal, zorder=2, positions=[5.0], whis='range', widths=boxplot_width, flierprops=flierprops, medianprops=medianprops, boxprops=boxprops, whiskerprops=whiskerprops, capprops=capprops)
ax.boxplot(subensembles_delta_pr_ccal, zorder=2, positions=[6.0], whis='range', widths=boxplot_width, flierprops=flierprops, medianprops=medianprops, boxprops=boxprops, whiskerprops=whiskerprops, capprops=capprops)
ax.boxplot(subensembles_delta_pr_scal, zorder=2, positions=[7.0], whis='range', widths=boxplot_width, flierprops=flierprops, medianprops=medianprops, boxprops=boxprops, whiskerprops=whiskerprops, capprops=capprops)

ax.text(s='all subensembles\n(N='+str(N_ens)+')', x=6.0, y=3.3, fontsize=fontsize, ha='center', va='bottom', color='firebrick')

flierprops = dict(marker='.', markeredgecolor='0.1', markerfacecolor='0.1')
medianprops = dict(linewidth=2, color='firebrick')
boxprops = dict(linewidth=2, color='0.1')
whiskerprops = dict(linewidth=2, color='0.1')
capprops = dict(linewidth=2, color='0.1')

ax.boxplot(optimal_subensembles_delta_pr_ncal, zorder=2, positions=[9.0], whis='range', widths=boxplot_width, flierprops=flierprops, medianprops=medianprops, boxprops=boxprops, whiskerprops=whiskerprops, capprops=capprops)
ax.boxplot(optimal_subensembles_delta_pr_ccal, zorder=2, positions=[10.0], whis='range', widths=boxplot_width, flierprops=flierprops, medianprops=medianprops, boxprops=boxprops, whiskerprops=whiskerprops, capprops=capprops)
ax.boxplot(optimal_subensembles_delta_pr_scal, zorder=2, positions=[11.0], whis='range', widths=boxplot_width, flierprops=flierprops, medianprops=medianprops, boxprops=boxprops, whiskerprops=whiskerprops, capprops=capprops)

# calculate percent change in range
ncal_fraction = (optimal_subensembles_delta_pr_ncal.max()-optimal_subensembles_delta_pr_ncal.min())/(model_delta_pr_ncal.max()-model_delta_pr_ncal.min())*100.
ccal_fraction = (optimal_subensembles_delta_pr_ccal.max()-optimal_subensembles_delta_pr_ccal.min())/(model_delta_pr_ccal.max()-model_delta_pr_ccal.min())*100.
scal_fraction = (optimal_subensembles_delta_pr_scal.max()-optimal_subensembles_delta_pr_scal.min())/(model_delta_pr_scal.max()-model_delta_pr_scal.min())*100.

ax.text(s='range\n'+'{:.0f}'.format(ncal_fraction)+'%', x=9.0, y=2.75, fontsize=fontsize, ha='center', va='top', color='firebrick')
ax.text(s='range\n'+'{:.0f}'.format(ccal_fraction)+'%', x=10.0, y=2.75, fontsize=fontsize, ha='center', va='top', color='firebrick')
ax.text(s='range\n'+'{:.0f}'.format(scal_fraction)+'%', x=11.0, y=2.75, fontsize=fontsize, ha='center', va='top', color='firebrick')

ax.text(s='Pareto-optimal\nsubensembles (N='+str(optimal_subensembles.shape[0])+')', x=10.0, y=3.3, fontsize=fontsize, ha='center', va='bottom', color='firebrick')

ax.set_xlim(0,12)
ax.set_ylim(-1.25,3.25)
ax.tick_params(labelsize=fontsize)
ax.set_ylabel('precip. change (mm day$^{\, -1}$)', fontsize=fontsize)
ax.set_xticklabels(['north\nCalif.', 'central\nCalif.', 'south\nCalif.', 'north\nCalif.', 'central\nCalif.', 'south\nCalif.', 'north\nCalif.', 'central\nCalif.', 'south\nCalif.'])
ax.set_xticks([1,2,3,5,6,7,9,10,11])
ax.grid()
ax.set_axisbelow(True)

fig.savefig('figs/box_plots_delta_pr_constrained_by_pr_sst.pdf', transparent=True, bbox_inches='tight')
